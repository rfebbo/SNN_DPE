# %%
from snn_dpe.tools.data import normalize_iris_data, read_iris_data
from snn_dpe.tools.plotting import plot_iris_data
from snn_dpe.encoder import Encoder

iris_data_location = '../../Datasets/Iris/iris.data'

# plot all of the data
iris_data, labels, classes, attributes = read_iris_data(iris_data_location, shuffle=False)

plot_iris_data(iris_data, classes, attributes, labels)

# %%
# plot just 2 classes and 2 attributes
iris_data, labels, classes, attributes = read_iris_data(iris_data_location, subset=True)
    
plot_iris_data(iris_data, classes, attributes, labels)

# %%
# read, normalize to values between 0 and 1, and plot
iris_data, labels, classes, attributes = read_iris_data(iris_data_location, shuffle=True)

normalized_iris_data = normalize_iris_data(iris_data, attributes)

plot_iris_data(normalized_iris_data, classes, attributes, labels)

# %%
# create one encoder per feature
# plot just 2 classes and 2 attributes
iris_data, labels, classes, attributes = read_iris_data(iris_data_location, subset=True)
normalized_iris_data = normalize_iris_data(iris_data, attributes)
