# %%
import numpy as np
import matplotlib.pyplot as plt

import sys
sys.path.append('../src')

from network_tools import create_network
from plotting_tools import plot_network

# %%
n_neurons = 16
n_synapses = int(n_neurons * np.random.uniform(low=2, high=3)) # random number from n_neurons * 2 to n_neurons * 3

Neurons = create_network(n_neurons, n_synapses)

plot_network(Neurons)
